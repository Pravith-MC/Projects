7.520714  28.094999
# ...                ...        ...         ...         ...        ...
# 2020-12-24  130.802322  51.044384  361.456879  131.970001  53.439999
# 2020-12-28  135.480576  51.732101  364.562042  136.690002  54.160000
# 2020-12-29  133.676666  51.703445  363.866547  134.869995  54.130001
# 2020-12-30  132.536850  51.999554  364.385712  133.720001  54.439999
# 2020-12-31  131.515961  52.381618  366.237122  132.690002  54.840000
#
# ...

# %%
Stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2770.000000  2770.000000  2770.000000  2770.000000  2770.000000
# mean     31.826626    33.699328   186.395074    33.768060    41.315493
# std      24.828085     8.566571    71.391679    24.573372     6.811654
# min       5.864508    17.134211    81.178398     6.858929    25.014999
# 25%      15.324006    27.834087   117.600452    17.471964    37.645000
# 50%      24.755189    33.237509   180.186775    26.985000    41.759998
# 75%      41.285795    39.373812   247.720352    42.996250    45.549999
# max     135.480576    55.534069   366.237122   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2770.000000  2770.000000  2770.000000  2770.000000  2770.000000
# ...

# %%
Stocks.loc[:,"Close"]
# Out:
#                   AAPL         KO         SPY
# Date
# 2009-12-31    7.526071  28.500000  111.440002
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2770 rows x 3 columns]

# %%
Close=Stocks.loc[:,"Close"].copy()
Close
# Out:
#                   AAPL         KO         SPY
# Date
# 2009-12-31    7.526071  28.500000  111.440002
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2770 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
Close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
Close.iloc[0,0]
# Out:
# 7.526071071624756

# %%
Close.AAPL
# Out:
# Date
# 2009-12-31      7.526071
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
#                  ...
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# 2020-12-31    132.690002
# Name: AAPL, Length: 2770, dtype: float64

# %%
Close.AAPL.div(Close.iloc[0,0])
# Out:
# Date
# 2009-12-31     1.000000
# 2010-01-04     1.015565
# 2010-01-05     1.017321
# 2010-01-06     1.001139
# 2010-01-07     0.999288
#                 ...
# 2020-12-24    17.535046
# 2020-12-28    18.162199
# 2020-12-29    17.920372
# 2020-12-30    17.767571
# 2020-12-31    17.630713
# Name: AAPL, Length: 2770, dtype: float64

# %%
Close.AAPL.div(Close.iloc[0,0]).mul(100)
# Out:
# Date
# 2009-12-31     100.000000
# 2010-01-04     101.556498
# 2010-01-05     101.732082
# 2010-01-06     100.113899
# 2010-01-07      99.928817
#                  ...
# 2020-12-24    1753.504584
# 2020-12-28    1816.219926
# 2020-12-29    1792.037224
# 2020-12-30    1776.757088
# 2020-12-31    1763.071345
# Name: AAPL, Length: 2770, dtype: float64

# %%
Close.iloc[0]
# Out:
# AAPL      7.526071
# KO       28.500000
# SPY     111.440002
# Name: 2009-12-31 00:00:00, dtype: float64

# %%
Close.div(Close.iloc[0]).mul(100)
# Out:
#                    AAPL          KO         SPY
# Date
# 2009-12-31   100.000000  100.000000  100.000000
# 2010-01-04   101.556498  100.070177  101.695979
# 2010-01-05   101.732082   98.859646  101.965178
# 2010-01-06   100.113899   98.824565  102.036968
# 2010-01-07    99.928817   98.578945  102.467696
# ...                 ...         ...         ...
# 2020-12-24  1753.504584  187.508767  331.119878
# 2020-12-28  1816.219926  190.035087  333.964470
# 2020-12-29  1792.037224  189.929828  333.327336
# 2020-12-30  1776.757088  191.017539  333.802927
# 2020-12-31  1763.071345  192.421053  335.498920
#
# [2770 rows x 3 columns]

# %%
normclose=Close.div(Close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
apl=Close.AAPL.copy().to_frame()

# %%
apl
# Out:
#                   AAPL
# Date
# 2009-12-31    7.526071
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2770 rows x 1 columns]

# %%
apl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2009-12-31         NaN
# 2010-01-04    7.526071
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2770 rows x 1 columns]

# %%
apl["lag1"]=apl.shift(periods=1)
apl
# Out:
#                   AAPL        lag1
# Date
# 2009-12-31    7.526071         NaN
# 2010-01-04    7.643214    7.526071
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2770 rows x 2 columns]

# %%
apl["diff"]=apl.AAPL.sub(apl.lag1)

# %%
apl["per"]=apl.AAPL.div(apl.lag1).sub(1).mul(100)

# %%
apl
# Out:
#                   AAPL        lag1      diff       per
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN
# 2010-01-04    7.643214    7.526071  0.117143  1.556498
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265
#
# [2770 rows x 4 columns]

# %%
apl["diff2"]=apl.AAPL.diff(periods=1)

# %%
apl
# Out:
#                   AAPL        lag1      diff       per     diff2
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN       NaN
# 2010-01-04    7.643214    7.526071  0.117143  1.556498  0.117143
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999
#
# [2770 rows x 5 columns]

# %%
apl["per2"]=apl.AAPL.pct_change(periods=1).mul(100)
apl
# Out:
#                   AAPL        lag1      diff       per     diff2      per2
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN       NaN       NaN
# 2010-01-04    7.643214    7.526071  0.117143  1.556498  0.117143  1.556498
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929 -0.184871
# ...                ...         ...       ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999 -0.770265
#
# [2770 rows x 6 columns]

# %%
del apl["per"]
apl
# Out:
#                   AAPL        lag1      diff     diff2      per2
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN       NaN
# 2010-01-04    7.643214    7.526071  0.117143  0.117143  1.556498
# 2010-01-05    7.656429    7.643214  0.013215  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.013929 -0.184871
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -1.029999 -0.770265
#
# [2770 rows x 5 columns]

# %%
apl.rename(columns={"per2":"change"}, inplace=True)
apl
# Out:
#                   AAPL        lag1      diff     diff2    change
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN       NaN
# 2010-01-04    7.643214    7.526071  0.117143  0.117143  1.556498
# 2010-01-05    7.656429    7.643214  0.013215  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.013929 -0.184871
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -1.029999 -0.770265
#
# [2770 rows x 5 columns]

# %%
apl.AAPL.resample("M").last()
# Out:
# Date
# 2009-12-31      7.526071
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: M, Name: AAPL, Length: 133, dtype: float64

# %%
apl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2009-12-31          NaN
# 2010-01-29    -8.859672
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BM, Name: AAPL, Length: 133, dtype: float64

# %%
apl
# Out:
#                   AAPL        lag1      diff     diff2    change
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN       NaN
# 2010-01-04    7.643214    7.526071  0.117143  0.117143  1.556498
# 2010-01-05    7.656429    7.643214  0.013215  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.013929 -0.184871
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -1.029999 -0.770265
#
# [2770 rows x 5 columns]

# %%
del apl["change"]

# %%
apl
# Out:
#                   AAPL        lag1      diff     diff2
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN
# 2010-01-04    7.643214    7.526071  0.117143  0.117143
# 2010-01-05    7.656429    7.643214  0.013215  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.013929
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999 -1.029999
#
# [2770 rows x 4 columns]

# %%
ret=apl.pct_change().dropna()    ### dropna for removing NAN frm results
ret
# Out:
#                 AAPL      lag1       diff      diff2
# Date
# 2010-01-05  0.001729  0.015565  -0.887193  -0.887193
# 2010-01-06 -0.015906  0.001729 -10.216000 -10.216000
# 2010-01-07 -0.001849 -0.015906  -0.885624  -0.885624
# 2010-01-08  0.006648 -0.001849  -4.589552  -4.589552
# 2010-01-11 -0.008821  0.006648  -2.335692  -2.335692
# ...              ...       ...        ...        ...
# 2020-12-24  0.007712 -0.006976  -2.097822  -2.097822
# 2020-12-28  0.035766  0.007712   3.673294   3.673294
# 2020-12-29 -0.013315  0.035766  -1.385595  -1.385595
# 2020-12-30 -0.008527 -0.013315  -0.368138  -0.368138
# 2020-12-31 -0.007703 -0.008527  -0.104344  -0.104344
#
# [2768 rows x 4 columns]

# %%
ret.plot(kind="hist",figsize=(12,8),bins=100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [172], in <cell line: 1>()
# ----> 1 ret.plot(kind="hist",figsize=(12,8),bins=100)
#       2 plt.show()
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:326, in MPLPlot.generate(self)
# ...

# %%
daily_mean_ret=ret.mean()

# %%
var_daily=ret.var()

# %%
std_daily=np.sqrt(var_daily)

# %%
annual_mean_ret=daily_mean_ret*252
annual_mean_ret
# Out:
# AAPL     0.300134
# lag1     0.302253
# diff          NaN
# diff2         NaN
# dtype: float64

# %%
annual_var_ret=var_daily*252
annual_var_ret
# Out:
# AAPL     0.080226
# lag1     0.080238
# diff          NaN
# diff2         NaN
# dtype: float64

# %%
annual_std_ret=np.sqrt(annual_var_ret)
annual_std_ret
# Out:
# AAPL     0.283242
# lag1     0.283263
# diff          NaN
# diff2         NaN
# dtype: float64

# %%
ticker=["SPY","AAPL","KO","MSFT","IBM","DIS"]

# %%
Stocks = yf.download(ticker,start ="2010-01-01",end ="2021-01-01")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
Stocks
# Out:
#              Adj Close                                                 \
#                   AAPL         DIS         IBM         KO        MSFT
# Date
# 2009-12-31    6.434924   28.090704   82.345901  19.343477   23.438801
# 2010-01-04    6.535085   27.933924   83.320938  19.357061   23.800228
# 2010-01-05    6.546384   27.864243   82.314445  19.122896   23.807913
# 2010-01-06    6.442255   27.716167   81.779724  19.116116   23.661808
# 2010-01-07    6.430346   27.724873   81.496620  19.068602   23.415733
# ...                ...         ...         ...        ...         ...
# 2020-12-24  130.802338  173.729996  110.801186  51.044380  219.930283
# 2020-12-28  135.480576  178.860001  110.916725  51.732098  222.112350
# 2020-12-29  133.676682  177.300003  110.010323  51.703449  221.312576
# 2020-12-30  132.536835  181.169998  110.490181  51.999546  218.873825
# 2020-12-31  131.515976  181.179993  111.858650  52.381622  219.604477
#
# ...

# %%
Close=Stocks.loc[:,"Close"].copy()

# %%
normclose=Close.div(Close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=Close.pct_change().dropna()

# %%
ret
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-04  0.015565 -0.005581  0.011841  0.000702  0.015420  0.016960
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007827  0.003890
# 2020-12-28  0.035766  0.029529  0.001043  0.013473  0.009921  0.008591
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.021827  0.004362  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.000055  0.012385  0.007348  0.003338  0.005081
#
# [2769 rows x 6 columns]

# %%
ret.describe()
# Out:
#               AAPL          DIS          IBM           KO         MSFT  \
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean      0.001196     0.000747     0.000086     0.000298     0.000846
# std       0.017841     0.015715     0.014132     0.011086     0.016012
# min      -0.128647    -0.129846    -0.128507    -0.096725    -0.147390
# 25%      -0.007121    -0.006209    -0.006321    -0.004696    -0.006936
# 50%       0.000905     0.000610     0.000289     0.000440     0.000655
# 75%       0.010384     0.007898     0.006759     0.005705     0.008638
# max       0.119808     0.144123     0.113010     0.064796     0.142169
#
#                SPY
# count  2769.000000
# mean      0.000497
# std       0.010911
# min      -0.109424
# 25%      -0.003531
# 50%       0.000637
# 75%       0.005426
# max       0.090603

# %%
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  2769.0  0.001196  0.017841 -0.128647 -0.007121  0.000905  0.010384
# DIS   2769.0  0.000747  0.015715 -0.129846 -0.006209  0.000610  0.007898
# IBM   2769.0  0.000086  0.014132 -0.128507 -0.006321  0.000289  0.006759
# KO    2769.0  0.000298  0.011086 -0.096725 -0.004696  0.000440  0.005705
# MSFT  2769.0  0.000846  0.016012 -0.147390 -0.006936  0.000655  0.008638
# SPY   2769.0  0.000497  0.010911 -0.109424 -0.003531  0.000637  0.005426
#
#            max
# AAPL  0.119808
# DIS   0.144123
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169
# SPY   0.090603

# %%
summary=ret.describe().T.loc[:,["std","mean"]]

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)
summary
# Out:
#            std      mean
# AAPL  0.283224  0.301443
# DIS   0.249466  0.188119
# IBM   0.224333  0.021718
# KO    0.175977  0.075128
# MSFT  0.254177  0.213242
# SPY   0.173210  0.125252

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)",fontsize=15)
plt.ylabel("Annual return",fontsize=15)
plt.title("Risk/return",fontsize=20)
plt.show()

# %%
ret.cov()  ## covariance
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  0.000318  0.000114  0.000110  0.000067  0.000158  0.000128
# DIS   0.000114  0.000247  0.000111  0.000085  0.000121  0.000121
# IBM   0.000110  0.000111  0.000200  0.000079  0.000121  0.000108
# KO    0.000067  0.000085  0.000079  0.000123  0.000076  0.000077
# MSFT  0.000158  0.000121  0.000121  0.000076  0.000256  0.000130
# SPY   0.000128  0.000121  0.000108  0.000077  0.000130  0.000119

# %%
ret.corr()   ## corelation
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  1.000000  0.408336  0.436236  0.339184  0.554168  0.659648
# DIS   0.408336  1.000000  0.497577  0.486494  0.480239  0.706195
# IBM   0.436236  0.497577  1.000000  0.502384  0.533257  0.703418
# KO    0.339184  0.486494  0.502384  1.000000  0.429696  0.639080
# MSFT  0.554168  0.480239  0.533257  0.429696  1.000000  0.744679
# SPY   0.659648  0.706195  0.703418  0.639080  0.744679  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()  ##should take stocks with corelation lessthan 0.50
